# %%
#imports

import pandas as pd
from geopy.geocoders import Nominatim
import folium
from geopy.exc import GeocoderTimedOut
import numpy as np

# %% [markdown]
# Notes:
# - Data received from https://catalog.data.gov/dataset/natural-gas-data-and-statistics
# - All units are in BCF
# - All measurements include dry natural gas

# %% [markdown]
# ## Data Extraction and Transformation

# %% [markdown]
# Production

# %%
# Read data

country_row = pd.read_csv('natural gas production.csv', header = None, skiprows=2, nrows=1)
production_df = pd.read_csv('natural gas production.csv', header = None, skiprows=5)

# Extract country names
country_names = []
for index in range(1, len(country_row.columns), 2):  # Assuming data is present in every second column starting from 1
    country_data = country_row[index].values[0]  # Get the first (and only) value of the series
    if isinstance(country_data, str) and len(country_data.split(",")) > 1:
        country_names.append(country_data.split(",")[1].strip())

# Transform dataframe to make it easier to manipulate

repeated_countrynames = [name for name in country_names for _ in range(2)]
production_df.columns = repeated_countrynames

df_T = production_df.T

reshaped_data = {
    'Country': [],
    'Year': [],
    'Production': []
}

for i in range(0, len(df_T), 2):
    country = df_T.index[i]
    # Check if index is multi-index and get the country name correctly
    if isinstance(country, tuple):
        country_name = country[0]
    else:
        country_name = country
    years = df_T.iloc[i].tolist()
    production = df_T.iloc[i+1].tolist()
    
    reshaped_data['Country'].extend([country_name] * len(years))
    reshaped_data['Year'].extend(years)
    reshaped_data['Production'].extend(production)

production = pd.DataFrame(reshaped_data)

# %% [markdown]
# Imports

# %%
# Read data

country_row = pd.read_csv('natural gas imports.csv', header = None, skiprows=2, nrows=1)
imports_df = pd.read_csv('natural gas imports.csv', header = None, skiprows=5)

# Extract country names
country_names = []
for index in range(1, len(country_row.columns), 2):  # Assuming data is present in every second column starting from 1
    country_data = country_row[index].values[0]  # Get the first (and only) value of the series
    if isinstance(country_data, str) and len(country_data.split(",")) > 1:
        country_names.append(country_data.split(",")[1].strip())

# Transform dataframe to make it easier to manipulate

repeated_countrynames = [name for name in country_names for _ in range(2)]
imports_df.columns = repeated_countrynames

df_T = imports_df.T

reshaped_data = {
    'Country': [],
    'Year': [],
    'Imports': []
}

for i in range(0, len(df_T), 2):
    country = df_T.index[i]
    # Check if index is multi-index and get the country name correctly
    if isinstance(country, tuple):
        country_name = country[0]
    else:
        country_name = country
    years = df_T.iloc[i].tolist()
    imports = df_T.iloc[i+1].tolist()
    
    reshaped_data['Country'].extend([country_name] * len(years))
    reshaped_data['Year'].extend(years)
    reshaped_data['Imports'].extend(imports)

imports = pd.DataFrame(reshaped_data)

# %% [markdown]
# Example of checking to see if databases are equivalent

# %%
(production['Country'] == imports['Country']).sum()
# Out:
# 9660

# %% [markdown]
# Exports

# %%
# Read data

country_row = pd.read_csv('natural gas exports.csv', header = None, skiprows=2, nrows=1)
exports_df = pd.read_csv('natural gas exports.csv', header = None, skiprows=5)

# Extract country names
country_names = []
for index in range(1, len(country_row.columns), 2):  # Assuming data is present in every second column starting from 1
    country_data = country_row[index].values[0]  # Get the first (and only) value of the series
    if isinstance(country_data, str) and len(country_data.split(",")) > 1:
        country_names.append(country_data.split(",")[1].strip())

# Transform dataframe to make it easier to manipulate

repeated_countrynames = [name for name in country_names for _ in range(2)]
exports_df.columns = repeated_countrynames

df_T = exports_df.T

reshaped_data = {
    'Country': [],
    'Year': [],
    'Exports': []
}

for i in range(0, len(df_T), 2):
    country = df_T.index[i]
    # Check if index is multi-index and get the country name correctly
    if isinstance(country, tuple):
        country_name = country[0]
    else:
        country_name = country
    years = df_T.iloc[i].tolist()
    exports = df_T.iloc[i+1].tolist()
    
    reshaped_data['Country'].extend([country_name] * len(years))
    reshaped_data['Year'].extend(years)
    reshaped_data['Exports'].extend(exports)

exports = pd.DataFrame(reshaped_data)

# %% [markdown]
# Consumption

# %%
# Read data

country_row = pd.read_csv('natural gas consumption.csv', header = None, skiprows=2, nrows=1)
consumption_df = pd.read_csv('natural gas consumption.csv', header = None, skiprows=5)

# Extract country names
country_names = []
for index in range(1, len(country_row.columns), 2):  # Assuming data is present in every second column starting from 1
    country_data = country_row[index].values[0]  # Get the first (and only) value of the series
    if isinstance(country_data, str) and len(country_data.split(",")) > 1:
        country_names.append(country_data.split(",")[1].strip())

# Transform dataframe to make it easier to manipulate

repeated_countrynames = [name for name in country_names for _ in range(2)]
consumption_df.columns = repeated_countrynames

df_T = consumption_df.T

reshaped_data = {
    'Country': [],
    'Year': [],
    'Consumption': []
}

for i in range(0, len(df_T), 2):
    country = df_T.index[i]
    # Check if index is multi-index and get the country name correctly
    if isinstance(country, tuple):
        country_name = country[0]
    else:
        country_name = country
    years = df_T.iloc[i].tolist()
    consumption = df_T.iloc[i+1].tolist()
    
    reshaped_data['Country'].extend([country_name] * len(years))
    reshaped_data['Year'].extend(years)
    reshaped_data['Consumption'].extend(consumption)

consumption = pd.DataFrame(reshaped_data)

# %% [markdown]
# Reserves

# %%
# Read data

country_row = pd.read_csv('natural gas reserves.csv', header = None, skiprows=2, nrows=1)
reserves_df = pd.read_csv('natural gas reserves.csv', header = None, skiprows=5)

# Extract country names
country_names = []
for index in range(1, len(country_row.columns), 2):  # Assuming data is present in every second column starting from 1
    country_data = country_row[index].values[0]  # Get the first (and only) value of the series
    if isinstance(country_data, str) and len(country_data.split(",")) > 1:
        country_names.append(country_data.split(",")[1].strip())

# Transform dataframe to make it easier to manipulate

repeated_countrynames = [name for name in country_names for _ in range(2)]
reserves_df.columns = repeated_countrynames

df_T = reserves_df.T

reshaped_data = {
    'Country': [],
    'Year': [],
    'Reserves': []
}

for i in range(0, len(df_T), 2):
    country = df_T.index[i]
    # Check if index is multi-index and get the country name correctly
    if isinstance(country, tuple):
        country_name = country[0]
    else:
        country_name = country
    years = df_T.iloc[i].tolist()
    reserves = df_T.iloc[i+1].tolist()
    
    reshaped_data['Country'].extend([country_name] * len(years))
    reshaped_data['Year'].extend(years)
    reshaped_data['Reserves'].extend(reserves)

reserves = pd.DataFrame(reshaped_data)

# %% [markdown]
# Combine dataframes

# %%
naturalgas_df = pd.concat([production[['Country', 'Year']], production['Production'], imports['Imports'], exports['Exports'], consumption['Consumption'], reserves['Reserves']], axis=1)

# %% [markdown]
# ## Data Cleaning/ Filtering

# %% [markdown]
# Notes
# - Used averaged data from 2017-2021 (last 5 years of avalable data)
# - removed countries that aren't recognized (e.g. Former Yugoslavia)

# %%
gas_truncated_year = naturalgas_df.loc[(naturalgas_df['Year'] >= 2017) & (naturalgas_df['Year'] <= 2021)]

# %% [markdown]
# Country check

# %%
countries = list(set(gas_truncated_year['Country']))

data = {'Country': countries}
df = pd.DataFrame(data)

geolocator = Nominatim(user_agent="applicable countrieslist", timeout=10)

def get_lat_lng(country_name):
    try:
        location = geolocator.geocode(country_name)
        if location:
            return location.latitude, location.longitude
        else:
            return None, None
    except GeocoderTimedOut:
        print(f"Error: Timed out for country {country_name}")
        return None, None
    except GeocoderServiceError as e:
        print(f"Service error for country {country_name}: {e}")
        return None, None
    except Exception as e:
        print(f"Unexpected error for country {country_name}: {e}")
        return None, None

unrecognized_countries = []

for index, country in enumerate(df['Country'], 1):
    print(f"Processing {index}/{len(df['Country'])}: {country}")
    time.sleep(1)
    lat, lng = get_lat_lng(country)
    if lat is None and lng is None:
        unrecognized_countries.append(country)

print("Unrecognized countries:", unrecognized_countries)
# Out:
# Processing 1/228: Mauritius
# Processing 2/228: New Zealand
# Processing 3/228: Ghana
# Processing 4/228: Ireland
# Processing 5/228: Senegal
# Processing 6/228: Iran
# Processing 7/228: Burkina Faso
# Processing 8/228: Cote d'Ivoire
# Processing 9/228: Cameroon
# Processing 10/228: Burundi
# Processing 11/228: Antigua and Barbuda
# Processing 12/228: Lithuania
# Processing 13/228: Palestinian Territories
# Processing 14/228: Netherlands
# Processing 15/228: Faroe Islands
# Processing 16/228: Portugal
# Processing 17/228: Uruguay
# Processing 18/228: Antarctica
# Processing 19/228: Bahrain
# Processing 20/228: Bangladesh
# Processing 21/228: North Korea
# Processing 22/228: Kenya
# Processing 23/228: World
# Processing 24/228: Tunisia
# Processing 25/228: Tajikistan
# Processing 26/228: Chad
# Processing 27/228: South Sudan
# Processing 28/228: India
# Processing 29/228: Israel
# Processing 30/228: Australia
# Processing 31/228: Belize
# Processing 32/228: Falkland Islands
# Processing 33/228: Puerto Rico
# Processing 34/228: Botswana
# Processing 35/228: Eritrea
# Processing 36/228: Micronesia
# Processing 37/228: Croatia
# Processing 38/228: Bolivia
# Processing 39/228: Netherlands Antilles
# Processing 40/228: American Samoa
# Processing 41/228: Pakistan
# Processing 42/228: Italy
# Processing 43/228: Brazil
# Processing 44/228: Panama
# Processing 45/228: Vanuatu
# Processing 46/228: Cyprus
# Processing 47/228: Estonia
# Processing 48/228: Afghanistan
# Processing 49/228: Papua New Guinea
# Processing 50/228: Mozambique
# Processing 51/228: Armenia
# Processing 52/228: Saint Vincent/Grenadines
# Processing 53/228: Greece
# Processing 54/228: United Arab Emirates
# Processing 55/228: Kazakhstan
# Processing 56/228: Finland
# Processing 57/228: Dominican Republic
# Processing 58/228: Slovakia
# Processing 59/228: Western Sahara
# Processing 60/228: Fiji
# Processing 61/228: Liberia
# Processing 62/228: British Virgin Islands
# Processing 63/228: Greenland
# Processing 64/228: Aruba
# Processing 65/228: Equatorial Guinea
# Processing 66/228: Albania
# Processing 67/228: Poland
# Processing 68/228: Bulgaria
# Processing 69/228: Belarus
# Processing 70/228: United Kingdom
# Processing 71/228: Gabon
# Processing 72/228: Brunei
# Processing 73/228: Central African Republic
# Processing 74/228: Wake Island
# Processing 75/228: French Guiana
# Processing 76/228: Zimbabwe
# Processing 77/228: Lebanon
# Processing 78/228: Serbia
# Processing 79/228: Rwanda
# Processing 80/228: Mauritania
# Processing 81/228: Laos
# Processing 82/228: Congo-Kinshasa
# Processing 83/228: Kiribati
# Processing 84/228: Grenada
# Processing 85/228: Singapore
# Processing 86/228: Burma
# Processing 87/228: Tuvalu
# Processing 88/228: Trinidad and Tobago
# Processing 89/228: Iceland
# Processing 90/228: Denmark
# Processing 91/228: Vietnam
# Processing 92/228: Martinique
# Processing 93/228: Former Yugoslavia
# Processing 94/228: Hong Kong
# Processing 95/228: Seychelles
# Processing 96/228: Taiwan
# Processing 97/228: New Caledonia
# Processing 98/228: Slovenia
# Processing 99/228: Benin
# Processing 100/228: Nicaragua
# Processing 101/228: Cuba
# Processing 102/228: Azerbaijan
# Processing 103/228: Tanzania
# Processing 104/228: Eswatini
# Processing 105/228: Argentina
# Processing 106/228: South Korea
# Processing 107/228: Indonesia
# Processing 108/228: Bermuda
# Processing 109/228: Luxembourg
# Processing 110/228: Canada
# Processing 111/228: Niue
# Processing 112/228: Turks and Caicos Islands
# Processing 113/228: Guinea
# Processing 114/228: Congo-Brazzaville
# Processing 115/228: Cabo Verde
# Processing 116/228: Turkmenistan
# Processing 117/228: Latvia
# Processing 118/228: Norway
# Processing 119/228: U.S. Virgin Islands
# Processing 120/228: Guam
# Processing 121/228: Malta
# Processing 122/228: Kyrgyzstan
# Processing 123/228: Timor-Leste
# Processing 124/228: Maldives
# Processing 125/228: Costa Rica
# Processing 126/228: Guatemala
# Processing 127/228: Egypt
# Processing 128/228: Belgium
# Processing 129/228: Philippines
# Processing 130/228: Jordan
# Processing 131/228: North Macedonia
# Processing 132/228: Niger
# Processing 133/228: Reunion
# Processing 134/228: Zambia
# Processing 135/228: Former Serbia and Montenegro
# Processing 136/228: El Salvador
# Processing 137/228: China
# Processing 138/228: Ukraine
# Processing 139/228: Russia
# Processing 140/228: Guinea-Bissau
# Processing 141/228: Bhutan
# Processing 142/228: Moldova
# Processing 143/228: Sao Tome and Principe
# Processing 144/228: Spain
# Processing 145/228: Cook Islands
# Processing 146/228: Former Czechoslovakia
# Processing 147/228: Oman
# Processing 148/228: Peru
# Processing 149/228: Dominica
# Processing 150/228: South Africa
# Processing 151/228: Georgia
# Processing 152/228: Somalia
# Processing 153/228: Uganda
# Processing 154/228: Libya
# Processing 155/228: Northern Mariana Islands
# Processing 156/228: Nepal
# Processing 157/228: Switzerland
# Processing 158/228: Chile
# Processing 159/228: Madagascar
# Processing 160/228: Sierra Leone
# Processing 161/228: Turkiye
# Processing 162/228: Venezuela
# Processing 163/228: Yemen
# Processing 164/228: Nauru
# Processing 165/228: French Polynesia
# Processing 166/228: Samoa
# Processing 167/228: Sweden
# Processing 168/228: Germany
# Processing 169/228: Hawaiian Trade Zone
# Processing 170/228: Romania
# Processing 171/228: Lesotho
# Processing 172/228: Gibraltar
# Processing 173/228: Iraq
# Processing 174/228: Syria
# Processing 175/228: Mali
# Processing 176/228: Kuwait
# Processing 177/228: Montenegro
# Processing 178/228: Bosnia and Herzegovina
# Processing 179/228: Mexico
# Processing 180/228: Qatar
# Processing 181/228: Malawi
# Processing 182/228: Former U.S.S.R.
# Processing 183/228: Uzbekistan
# Processing 184/228: Djibouti
# Processing 185/228: Colombia
# Processing 186/228: Saint Pierre and Miquelon
# Processing 187/228: Haiti
# Processing 188/228: Japan
# Processing 189/228: Sri Lanka
# Processing 190/228: France
# Processing 191/228: Hungary
# Processing 192/228: Suriname
# Processing 193/228: United States
# Processing 194/228: Czechia
# Processing 195/228: Tonga
# Processing 196/228: Malaysia
# Processing 197/228: Honduras
# Processing 198/228: Gambia
# Processing 199/228: Saint Lucia
# Processing 200/228: Ecuador
# Processing 201/228: The Bahamas
# Processing 202/228: Mongolia
# Processing 203/228: Algeria
# Processing 204/228: Namibia
# Processing 205/228: Sudan
# Processing 206/228: Saint Helena
# Processing 207/228: Angola
# Processing 208/228: Saint Kitts and Nevis
# Processing 209/228: Cambodia
# Processing 210/228: Solomon Islands
# Processing 211/228: Morocco
# Processing 212/228: Ethiopia
# Processing 213/228: Guyana
# Processing 214/228: Guadeloupe
# Processing 215/228: Nigeria
# Processing 216/228: U.S. Pacific Islands
# Processing 217/228: Macau
# Processing 218/228: Togo
# Processing 219/228: Barbados
# Processing 220/228: Kosovo
# Processing 221/228: Comoros
# Processing 222/228: Montserrat
# Processing 223/228: Paraguay
# Processing 224/228: Austria
# Processing 225/228: Thailand
# Processing 226/228: Cayman Islands
# Processing 227/228: Saudi Arabia
# Processing 228/228: Jamaica
# Unrecognized countries: ['Former Yugoslavia', 'Former Serbia and Montenegro', 'Former Czechoslovakia', 'Hawaiian Trade Zone', 'Former U.S.S.R.', 'U.S. Pacific Islands']

# %%
unrecognized_countries
# Out:
# ['Former Yugoslavia',
#  'Former Serbia and Montenegro',
#  'Former Czechoslovakia',
#  'Hawaiian Trade Zone',
#  'Former U.S.S.R.',
#  'U.S. Pacific Islands']

# %%
# Remove rows with unrecognized countries
gas_filtered = gas_truncated_year[~gas_truncated_year['Country'].isin(unrecognized_countries)]

gas_filtered
# Out:
#      Country    Year Production Imports Exports Consumption Reserves
# 37     Aruba  2017.0          0       0       0           0        0
# 38     Aruba  2018.0          0       0       0           0        0
# 39     Aruba  2019.0          0       0       0           0        0
# 40     Aruba  2020.0          0       0       0           0        0
# 41     Aruba  2021.0          0       0       0           0        0
# ...      ...     ...        ...     ...     ...         ...      ...
# 9655  Kosovo  2017.0          0       0       0           0        0
# 9656  Kosovo  2018.0          0       0       0           0        0
# 9657  Kosovo  2019.0          0       0       0           0        0
# 9658  Kosovo  2020.0          0       0       0           0        0
# 9659  Kosovo  2021.0          0       0       0           0        0
#
# [1120 rows x 7 columns]

# %%
#convert to numerical form

numeric_cols = ['Production', 'Imports', 'Exports', 'Consumption', 'Reserves']
non_numeric_rows = gas_filtered[gas_filtered[numeric_cols].applymap(lambda x: not isinstance(x, (int, float))).any(axis=1)]

print(non_numeric_rows)

for col in numeric_cols:
    gasfiltered[col] = pd.to_numeric(gas_filtered[col], errors='coerce')

# take average of last five years

avg_gas = gas_filtered.groupby('Country').agg({
    'Production': 'mean',
    'Imports': 'mean',
    'Exports': 'mean',
    'Consumption': 'mean',
    'Reserves': 'mean'
}).reset_index()

# %% [markdown]
# ## Visualizations

# %%
# Create a base map
m = folium.Map(location=[45, -100], zoom_start=4)

geolocator = Nominatim(user_agent="geoapi")
for i, row in avg_gas.iterrows():
    location = geolocator.geocode(row['Country'])
    
    # Skip countries with Imports value of 0
    if row['Imports'] == 0:
        continue

    if location:
        # Using logarithmic scaling for the radius to account for the skewed distribution
        radius = np.log(row['Imports'] + 1)
        
        folium.CircleMarker(
            location=[location.latitude, location.longitude],
            radius=radius,
            popup=f"{row['Country']} - Imports: {row['Imports']}",
            fill=True,
            color="green",
            fill_color="green"
        ).add_to(m)

m.save("imports.html")

# %%
m = folium.Map(location=[45, -100], zoom_start=4)

geolocator = Nominatim(user_agent="geoapi")
for i, row in avg_gas.iterrows():
    location = geolocator.geocode(row['Country'])
    
    # Skip countries with Imports value of 0
    if row['Exports'] == 0:
        continue

    if location:
        # Using logarithmic scaling for the radius to account for the skewed distribution
        radius = np.log(row['Exports'] + 1)
        
        folium.CircleMarker(
            location=[location.latitude, location.longitude],
            radius=radius,
            popup=f"{row['Country']} - Exports: {row['Exports']}",
            fill=True,
            color="green",
            fill_color="green"
        ).add_to(m)

m.save("exports.html")

# %%
m = folium.Map(location=[45, -100], zoom_start=4)

geolocator = Nominatim(user_agent="geoapi")
for i, row in avg_gas.iterrows():
    location = geolocator.geocode(row['Country'])
    
    # Skip countries with Imports value of 0
    if row['Production'] == 0:
        continue

    if location:
        # Using logarithmic scaling for the radius to account for the skewed distribution
        radius = np.log(row['Production'] + 1)
        
        folium.CircleMarker(
            location=[location.latitude, location.longitude],
            radius=radius,
            popup=f"{row['Country']} - Production: {row['Production']}",
            fill=True,
            color="green",
            fill_color="green"
        ).add_to(m)

m.save("production.html")

# %%
m = folium.Map(location=[45, -100], zoom_start=4)

geolocator = Nominatim(user_agent="geoapi")
for i, row in avg_gas.iterrows():
    location = geolocator.geocode(row['Country'])
    
    # Skip countries with Imports value of 0
    if row['Consumption'] == 0:
        continue

    if location:
        # Using logarithmic scaling for the radius to account for the skewed distribution
        radius = np.log(row['Consumption'] + 1)
        
        folium.CircleMarker(
            location=[location.latitude, location.longitude],
            radius=radius,
            popup=f"{row['Country']} - Consumption: {row['Consumption']}",
            fill=True,
            color="green",
            fill_color="green"
        ).add_to(m)

m.save("consumption.html")

# %%
m = folium.Map(location=[45, -100], zoom_start=4)

geolocator = Nominatim(user_agent="geoapi")
for i, row in avg_gas.iterrows():
    location = geolocator.geocode(row['Country'])
    
    # Skip countries with Imports value of 0
    if row['Reserves'] == 0:
        continue

    if location:
        # Using logarithmic scaling for the radius to account for the skewed distribution
        radius = np.log(row['Reserves'] + 1)
        
        folium.CircleMarker(
            location=[location.latitude, location.longitude],
            radius=radius,
            popup=f"{row['Country']} - Reserves: {row['Reserves']}",
            fill=True,
            color="green",
            fill_color="green"
        ).add_to(m)

m.save("Reserves.html")
